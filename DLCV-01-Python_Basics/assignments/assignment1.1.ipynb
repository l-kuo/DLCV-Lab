# %% [markdown]
# # Assignment 1.1
#
# ## Python Fundamentals
#
# **Estimated Time:** 1 Hour
#
# **Instructions:** Create a single notebook file. Write Python code to complete each of the tasks below in order. Use comments to label each task number in your file.
#
# ---
#
# ### Task 1: Personal Introduction
#
# This task focuses on **variable definition**, **basic data types** (`string`, `int`), and **basic syntax** (`print()`).
#
# 1.  Create a variable called `my_name` and assign your name to it as a string.
# 2.  Create a variable called `my_age` and assign your age to it as an integer.
# 3.  Create a variable `is_learning_python` and set it to the boolean value `True`.
# 4.  Write a single `print()` statement that uses an f-string to introduce yourself.
#
# *Example Output:*
# ```
# Hello, my name is Alex and I am 20 years old. It's True that I am learning Python!
# ```
#
# ---
#
# ### Task 2: My Favorite Hobbies
#
# This task focuses on **Lists**, the `list()` constructor, and **Set** operations.
#
# 1.  Create a list named `hobbies_list` containing at least five of your hobbies. Make sure to include one hobby twice to create a duplicate.
# 2.  Use the `set()` constructor to create a new set called `unique_hobbies` from `hobbies_list`.
# 3.  Create another set called `friend_hobbies` with at least three hobbies, where one is the same as one of your unique hobbies.
# 4.  Find the hobbies you and your friend have in common using the `intersection()` method. Store the result in a variable called `common_hobbies`.
# 5.  Print your set of unique hobbies and the set of common hobbies.
#
# *Example Output:*
# ```
# My unique hobbies are: {'cooking', 'gaming', 'reading', 'hiking'}
# Our common hobbies are: {'reading'}
# ```
#
# ---
#
# ### Task 3: The Ultimate Movie Log
#
# This task features more complex **List** and **Dictionary** operations. 🎬
#
# #### Part A: Complex List Operations
#
# 1.  Create a list of strings called `watched_movies` with three movies you have already seen.
# 2.  Create a second list called `watchlist` with two movies you want to see.
# 3.  Create a new list called `full_movie_library` by **concatenating** `watched_movies` and `watchlist` using the `+` operator.
# 4.  Use the `.pop()` method to remove the first movie from your `watchlist` and store its title in a new variable called `just_watched`.
# 5.  Print a confirmation message, for example: `"I just finished watching [just_watched]!"`
# 6.  Use the `.remove()` method to remove one movie from `full_movie_library` by its exact title.
# 7.  **Sort** the `full_movie_library` alphabetically in place using the `.sort()` method and print the final, sorted library.
#
# *Example Output for Part A:*
# ```
# I just finished watching The Grand Budapest Hotel!
# My final movie library: ['Dune', 'Inception', 'Parasite', 'The Matrix']
# ```
#
# #### Part B: Complex Dictionary Operations
#
# 1.  Create a dictionary called `movie_ratings` for the movies in your original `watched_movies` list. The keys should be the movie titles (strings) and the values should be your rating from 1 to 10 (integers).
# 2.  **Update the value** for one of the movies in `movie_ratings` to a new number.
# 3.  Add the movie you just watched (`just_watched` from Part A) to the `movie_ratings` dictionary with its rating.
# 4.  Use the `.get()` method to look for a movie title that *does not exist* in `movie_ratings`. Provide a default value of `"Not Rated"`. Store the result in `queried_rating` and print it.
# 5.  Use the `del` keyword to **delete one key-value pair** from `movie_ratings`.
# 6.  Print the final `movie_ratings` dictionary.
#
# *Example Output for Part B:*
# ```
# Rating for 'Avatar': Not Rated
# Final Movie Ratings: {'Inception': 10, 'The Matrix': 9, 'The Grand Budapest Hotel': 9}
# ```
#
# ---
#
# ### Task 4: Final Summary
#
# This final task is a quick review of printing different data types.
#
# 1.  Print the number of movies in your `full_movie_library` using the `len()` function.
# 2.  Get a list of all the titles from your final `movie_ratings` dictionary using the `.keys()` method. (Hint: You may need to wrap it with the `list()` constructor). Print this list.
# 3.  Print the data type of each of the following variables using the `type()` function:
#     * `my_age`
#     * `full_movie_library`
#     * `queried_rating`
#     * `movie_ratings`
#
# *Example Output:*
# ```
# My final movie library has 4 movies.
# Movie titles I have rated: ['Inception', 'The Matrix', 'The Grand Budapest Hotel']
# Type of my_age: <class 'int'>
# Type of full_movie_library: <class 'list'>
# Type of queried_rating: <class 'str'>
# Type of movie_ratings: <class 'dict'>
# ```
